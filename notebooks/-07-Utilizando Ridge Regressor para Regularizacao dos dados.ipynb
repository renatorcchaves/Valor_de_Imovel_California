# %% [markdown]
# ## <font color = 'darkblue'> **Sequência para chegar no melhor modelo**
#
# 1) Feito uma grande Análise Exploratória
#
# 2) Avaliando os dados geográficos com Geopandas
#
# 3) Desenvolvido notebook para o projeto de Machine Learning, com funções que podem facilitar testes de diferentes modelos
#
# 4) **Aprimorar o modelo de Machine Learning, seguindo as etapas abaixo:**
#     - Linear Regression com preprocessamento só colunas categóricas, comparando com Dummy Regressor
#     - Avaliado se a transformação de target melhorava modelo, e testado qual transformação de target era melhor (PowerTransform ou Quantile Transform)
#     - Testado diferentes preprocessamento para colunas numéricas (só RobustScaler ou Standard Scaler + Power Transform) com a melhor transformação de target anterior
#     - Aplicado Polynomial Features para verifical qual grau do modelo ficava melhor, apenas com Robust Scaler para colunas numéricas e QuantileTransform para o target
#     - Substituído o Linear Regression pelo Elastic Net para verificar se alguma regularização melhorava o modelo
#     - **Substituído o ElasticNet pelo Ridge para verificar os resultado, definindo finalmente o melhor modelo**
#
# 5) Salvar o melhor modelo

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from src.config import DADOS_LIMPOS, PASTA_RELATORIOS

#from src.auxiliares import dataframe_coeficientes
#from src.graficos import (
#    plot_coeficientes,
#    plot_comparar_metricas_modelos,
#    plot_residuos_estimador,
#)
#from src.models import (
#    organiza_resultados,
#    treinar_e_validar_modelo_regressao,
#    grid_search_cv_regressor,
#)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %% [markdown]
# #### **Fórmulas usadas para geração e avaliação dos modelos de machine learning deste projeto**
#
# OBS: Expandir a célula abaixo caso queira consultar as fórmulas

# %%
# Função para construir o pipeline do modelo d e regressão, caso exista ou não etapas de preprocessamento e transformação de target
def construir_pipeline_modelo_regressao(
    regressor, preprocessor=None, target_transformer=None
):
    if preprocessor is not None:
        pipeline = Pipeline([("preprocessor", preprocessor), ("reg", regressor)])
    else:
        pipeline = Pipeline([("reg", regressor)])

    if target_transformer is not None:
        model = TransformedTargetRegressor(
            regressor=pipeline, transformer=target_transformer
        )
    else:
        model = pipeline
    return model

# Função treinar o modelo de regressão e retornar os scores da validação cruzada
def treinar_e_validar_modelo_regressao(
    X,
    y,
    regressor,
    preprocessor=None,
    target_transformer=None,
    n_splits=5,
    random_state=RANDOM_STATE,
):

    model = construir_pipeline_modelo_regressao(
        regressor, preprocessor, target_transformer
    )

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    scores = cross_validate(
        model,
        X,
        y,
        cv=kf,
        scoring=[
            "r2",
            "neg_mean_absolute_error",
            "neg_root_mean_squared_error",
        ],
    )

    return scores

# Após aplicar a função "treinar_e_validar_modelo_regressao" é aplicado essa função para obter um dataframe com as métricas de avaliação do modelo de regressão de acordo com a validação cruzada
def organiza_resultados(resultados):

    for chave, valor in resultados.items():
        resultados[chave]["time_seconds"] = (
            resultados[chave]["fit_time"] + resultados[chave]["score_time"]
        )

    df_resultados = (
        pd.DataFrame(resultados).T.reset_index().rename(columns={"index": "model"})
    )

    df_resultados_expandido = df_resultados.explode(
        df_resultados.columns[1:].to_list()
    ).reset_index(drop=True)

    try:
        df_resultados_expandido = df_resultados_expandido.apply(pd.to_numeric)
    except ValueError:
        pass

    return df_resultados_expandido

# Após aplicar a função "organiza_resultados(resultados)" é aplicado essa função para transformar os dados do dataframe em 4 gráficos
def plot_comparar_metricas_modelos(df_resultados):
    fig, axs = plt.subplots(2, 2, figsize=(8, 8), sharex=True)

    comparar_metricas = [
        "time_seconds",
        "test_r2",
        "test_neg_mean_absolute_error",
        "test_neg_root_mean_squared_error",
    ]

    nomes_metricas = [
        "Tempo (s)",
        "R²",
        "MAE",
        "RMSE",
    ]

    for ax, metrica, nome in zip(axs.flatten(), comparar_metricas, nomes_metricas):
        sns.boxplot(
            x="model",
            y=metrica,
            data=df_resultados,
            ax=ax,
            showmeans=True,
        )
        ax.set_title(nome)
        ax.set_ylabel(nome)
        ax.tick_params(axis="x", rotation=90)

    plt.tight_layout()

    plt.show()

# Função criada para utilizar a ferramenta grid_search para obter quais são os melhores parâmetros para o modelo de machine learning
def grid_search_cv_regressor(
    regressor,
    param_grid,
    preprocessor=None,
    target_transformer=None,
    n_splits=5,
    random_state=RANDOM_STATE,
    return_train_score=False,
):
    model = construir_pipeline_modelo_regressao(
        regressor, preprocessor, target_transformer
    )

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    grid_search = GridSearchCV(
        model,
        cv=kf,
        param_grid=param_grid,
        scoring=["r2", "neg_mean_absolute_error", "neg_root_mean_squared_error"],
        refit="neg_root_mean_squared_error",
        n_jobs=-1,
        return_train_score=return_train_score,
        verbose=1,
    )

    return grid_search

# Após ter definido o melhor modelo, é aplicado essa formula para comparar os dados previstos com os dados de teste
def plot_residuos_estimador(estimator, X, y, eng_formatter=False, fracao_amostra=0.25):

    fig, axs = plt.subplots(1, 3, figsize=(12, 6))

    error_display_01 = PredictionErrorDisplay.from_estimator(
        estimator,
        X,
        y,
        kind="residual_vs_predicted",
        ax=axs[1],
        random_state=RANDOM_STATE,
        scatter_kwargs={"alpha": SCATTER_ALPHA},
        subsample=fracao_amostra,                       # Mostra o percentual dos dados que serão exibidos no gráfico
    )

    error_display_02 = PredictionErrorDisplay.from_estimator(
        estimator,
        X,
        y,
        kind="actual_vs_predicted",
        ax=axs[2],
        random_state=RANDOM_STATE,
        scatter_kwargs={"alpha": SCATTER_ALPHA},
        subsample=fracao_amostra,
    )

    residuos = error_display_01.y_true - error_display_01.y_pred

    sns.histplot(residuos, kde=True, ax=axs[0])

    if eng_formatter:                                              # É só pra melhorar a legenda dos eixos X e y, em vez de deixar 100000 e 20000 fica 100k e 200k
        for ax in axs:
            ax.yaxis.set_major_formatter(EngFormatter())
            ax.xaxis.set_major_formatter(EngFormatter())

    plt.tight_layout()

    plt.show()

# %% [markdown]
# #### **Separação das colunas do dataframe**

# %%
coluna_target = ['median_house_value']

coluna_one_hot_encoder = ['ocean_proximity']

coluna_ordinal_enconder = ['median_income_cat']

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_enconder)
colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %% [markdown]
# #### **Definido o *"Preprocessamento Simples"* no notebook anterior para aplicar o *"Polynomial Features"***
# - Foi o preprocessamento que trouxe melhores resultados pelo GridSearch no notebook anterior
# - **OBS:** PolynomialFeatures() é uma etapa de *PREPROCESSAMENTO* dentro do Pipeline, pode até ser usada como um regressor, mas nesse exemplo está sendo usada junto com o modelo de LinearRegression </font>

# %%
pipeline_robust = Pipeline(steps = [
    ('robust_scaler', RobustScaler()),
    ('poly', PolynomialFeatures(degree=1, include_bias=False))             # Inicialmente será grau 1, mas vamos testar outros graus com o grid search
])

preprocessamento = ColumnTransformer(
    transformers = [
        ('one_hot_encoder', OneHotEncoder(drop='first'), coluna_one_hot_encoder),         # drop='first' --> Para reduzir o número de colunas no preprocessamento
        ('ordinal_encoder', OrdinalEncoder(categories='auto'), coluna_ordinal_enconder),
        ('robust_scaler_poly', pipeline_robust, colunas_robust_scaler)      
    ],
)

# %%
preprocessamento
# Out:
# ColumnTransformer(transformers=[('one_hot_encoder', OneHotEncoder(drop='first'),
#                                  ['ocean_proximity']),
#                                 ('ordinal_encoder', OrdinalEncoder(),
#                                  ['median_income_cat']),
#                                 ('robust_scaler_poly',
#                                  Pipeline(steps=[('robust_scaler',
#                                                   RobustScaler()),
#                                                  ('poly',
#                                                   PolynomialFeatures(degree=1,
#                                                                      include_bias=False))]),
#                                  Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object'))])

# %% [markdown]
# #### **Colocando parâmetros apenas do modelo Ridge para serem testados pelo GridSearchCV***
#
# **OBS**: Esse modelo foi escolhido pois no notebook anterior o melhor modelo obtido pelo GridSearchCV foi do modelo ElasticNet com parâmetro do alpha = 0.01 (ElasticNet com alpha = 0 é o modelo Ridge)

# %%
param_grid = {
    'regressor__preprocessor__robust_scaler_poly__poly__degree': [1, 2, 3],
    'regressor__reg__alpha': [1E-2, 5E-2, 0.1, 0.25, 0.5, 1, 2, 5, 10, 20, 100],                     # Alpha = 0 o ElasticNet fica igual ao Linear Regression
}

# %%
grid_search = grid_search_cv_regressor(
    regressor= Ridge(),
    preprocessor = preprocessamento,             
    target_transformer = QuantileTransformer(output_distribution='normal'),                # Já foi definido no notebook anterior que o QuantileTransformer trouxe melhores resultados
    param_grid = param_grid
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sc...
#                                                                             ('reg',
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1, 2, 5, 10, 20, 100]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 33 candidates, totalling 165 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_sc...
#                                                                             ('reg',
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1, 2, 5, 10, 20, 100]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 10}

# %%
grid_search.best_score_
# Out:
# -50453.59696711613

# %%
grid_search.best_estimator_
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                       ColumnTransformer(transformers=[('one_hot_encoder',
#                                                                                        OneHotEncoder(drop='first'),
#                                                                                        ['ocean_proximity']),
#                                                                                       ('ordinal_encoder',
#                                                                                        OrdinalEncoder(),
#                                                                                        ['median_income_cat']),
#                                                                                       ('robust_scaler_poly',
#                                                                                        Pipeline(steps=[('robust_scaler',
#                                                                                                         RobustScaler()),
#                                                                                                        ('poly',
#                                                                                                         PolynomialFeatures(degree=3,
#                                                                                                                            include_bias=False))]),
#                                                                                        Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object'))])),
#                                                      ('reg', Ridge(alpha=10))]),
#                            transformer=QuantileTransformer(output_distribution='normal'))

# %%
grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out()
# Out:
# array(['one_hot_encoder__ocean_proximity_INLAND',
#        'one_hot_encoder__ocean_proximity_NEAR BAY',
#        'one_hot_encoder__ocean_proximity_NEAR OCEAN',
#        'ordinal_encoder__median_income_cat',
#        'robust_scaler_poly__bedrooms_per_room',
#        'robust_scaler_poly__households',
#        'robust_scaler_poly__housing_median_age',
#        'robust_scaler_poly__latitude', 'robust_scaler_poly__longitude',
#        'robust_scaler_poly__median_income',
#        'robust_scaler_poly__population',
#        'robust_scaler_poly__population_per_household',
#        'robust_scaler_poly__rooms_per_household',
#        'robust_scaler_poly__total_bedrooms',
#        'robust_scaler_poly__total_rooms',
#        'robust_scaler_poly__bedrooms_per_room^2',
#        'robust_scaler_poly__bedrooms_per_room households',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age',
#        'robust_scaler_poly__bedrooms_per_room latitude',
#        'robust_scaler_poly__bedrooms_per_room longitude',
#        'robust_scaler_poly__bedrooms_per_room median_income',
#        'robust_scaler_poly__bedrooms_per_room population',
#        'robust_scaler_poly__bedrooms_per_room population_per_household',
#        'robust_scaler_poly__bedrooms_per_room rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room total_rooms',
#        'robust_scaler_poly__households^2',
#        'robust_scaler_poly__households housing_median_age',
#        'robust_scaler_poly__households latitude',
#        'robust_scaler_poly__households longitude',
#        'robust_scaler_poly__households median_income',
#        'robust_scaler_poly__households population',
#        'robust_scaler_poly__households population_per_household',
#        'robust_scaler_poly__households rooms_per_household',
#        'robust_scaler_poly__households total_bedrooms',
#        'robust_scaler_poly__households total_rooms',
#        'robust_scaler_poly__housing_median_age^2',
#        'robust_scaler_poly__housing_median_age latitude',
#        'robust_scaler_poly__housing_median_age longitude',
#        'robust_scaler_poly__housing_median_age median_income',
#        'robust_scaler_poly__housing_median_age population',
#        'robust_scaler_poly__housing_median_age population_per_household',
#        'robust_scaler_poly__housing_median_age rooms_per_household',
#        'robust_scaler_poly__housing_median_age total_bedrooms',
#        'robust_scaler_poly__housing_median_age total_rooms',
#        'robust_scaler_poly__latitude^2',
#        'robust_scaler_poly__latitude longitude',
#        'robust_scaler_poly__latitude median_income',
#        'robust_scaler_poly__latitude population',
#        'robust_scaler_poly__latitude population_per_household',
#        'robust_scaler_poly__latitude rooms_per_household',
#        'robust_scaler_poly__latitude total_bedrooms',
#        'robust_scaler_poly__latitude total_rooms',
#        'robust_scaler_poly__longitude^2',
#        'robust_scaler_poly__longitude median_income',
#        'robust_scaler_poly__longitude population',
#        'robust_scaler_poly__longitude population_per_household',
#        'robust_scaler_poly__longitude rooms_per_household',
#        'robust_scaler_poly__longitude total_bedrooms',
#        'robust_scaler_poly__longitude total_rooms',
#        'robust_scaler_poly__median_income^2',
#        'robust_scaler_poly__median_income population',
#        'robust_scaler_poly__median_income population_per_household',
#        'robust_scaler_poly__median_income rooms_per_household',
#        'robust_scaler_poly__median_income total_bedrooms',
#        'robust_scaler_poly__median_income total_rooms',
#        'robust_scaler_poly__population^2',
#        'robust_scaler_poly__population population_per_household',
#        'robust_scaler_poly__population rooms_per_household',
#        'robust_scaler_poly__population total_bedrooms',
#        'robust_scaler_poly__population total_rooms',
#        'robust_scaler_poly__population_per_household^2',
#        'robust_scaler_poly__population_per_household rooms_per_household',
#        'robust_scaler_poly__population_per_household total_bedrooms',
#        'robust_scaler_poly__population_per_household total_rooms',
#        'robust_scaler_poly__rooms_per_household^2',
#        'robust_scaler_poly__rooms_per_household total_bedrooms',
#        'robust_scaler_poly__rooms_per_household total_rooms',
#        'robust_scaler_poly__total_bedrooms^2',
#        'robust_scaler_poly__total_bedrooms total_rooms',
#        'robust_scaler_poly__total_rooms^2',
#        'robust_scaler_poly__bedrooms_per_room^3',
#        'robust_scaler_poly__bedrooms_per_room^2 households',
#        'robust_scaler_poly__bedrooms_per_room^2 housing_median_age',
#        'robust_scaler_poly__bedrooms_per_room^2 latitude',
#        'robust_scaler_poly__bedrooms_per_room^2 longitude',
#        'robust_scaler_poly__bedrooms_per_room^2 median_income',
#        'robust_scaler_poly__bedrooms_per_room^2 population',
#        'robust_scaler_poly__bedrooms_per_room^2 population_per_household',
#        'robust_scaler_poly__bedrooms_per_room^2 rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room^2 total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room^2 total_rooms',
#        'robust_scaler_poly__bedrooms_per_room households^2',
#        'robust_scaler_poly__bedrooms_per_room households housing_median_age',
#        'robust_scaler_poly__bedrooms_per_room households latitude',
#        'robust_scaler_poly__bedrooms_per_room households longitude',
#        'robust_scaler_poly__bedrooms_per_room households median_income',
#        'robust_scaler_poly__bedrooms_per_room households population',
#        'robust_scaler_poly__bedrooms_per_room households population_per_household',
#        'robust_scaler_poly__bedrooms_per_room households rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room households total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room households total_rooms',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age^2',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age latitude',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age longitude',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age median_income',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age population',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age population_per_household',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room housing_median_age total_rooms',
#        'robust_scaler_poly__bedrooms_per_room latitude^2',
#        'robust_scaler_poly__bedrooms_per_room latitude longitude',
#        'robust_scaler_poly__bedrooms_per_room latitude median_income',
#        'robust_scaler_poly__bedrooms_per_room latitude population',
#        'robust_scaler_poly__bedrooms_per_room latitude population_per_household',
#        'robust_scaler_poly__bedrooms_per_room latitude rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room latitude total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room latitude total_rooms',
#        'robust_scaler_poly__bedrooms_per_room longitude^2',
#        'robust_scaler_poly__bedrooms_per_room longitude median_income',
#        'robust_scaler_poly__bedrooms_per_room longitude population',
#        'robust_scaler_poly__bedrooms_per_room longitude population_per_household',
#        'robust_scaler_poly__bedrooms_per_room longitude rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room longitude total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room longitude total_rooms',
#        'robust_scaler_poly__bedrooms_per_room median_income^2',
#        'robust_scaler_poly__bedrooms_per_room median_income population',
#        'robust_scaler_poly__bedrooms_per_room median_income population_per_household',
#        'robust_scaler_poly__bedrooms_per_room median_income rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room median_income total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room median_income total_rooms',
#        'robust_scaler_poly__bedrooms_per_room population^2',
#        'robust_scaler_poly__bedrooms_per_room population population_per_household',
#        'robust_scaler_poly__bedrooms_per_room population rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room population total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room population total_rooms',
#        'robust_scaler_poly__bedrooms_per_room population_per_household^2',
#        'robust_scaler_poly__bedrooms_per_room population_per_household rooms_per_household',
#        'robust_scaler_poly__bedrooms_per_room population_per_household total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room population_per_household total_rooms',
#        'robust_scaler_poly__bedrooms_per_room rooms_per_household^2',
#        'robust_scaler_poly__bedrooms_per_room rooms_per_household total_bedrooms',
#        'robust_scaler_poly__bedrooms_per_room rooms_per_household total_rooms',
#        'robust_scaler_poly__bedrooms_per_room total_bedrooms^2',
#        'robust_scaler_poly__bedrooms_per_room total_bedrooms total_rooms',
#        'robust_scaler_poly__bedrooms_per_room total_rooms^2',
#        'robust_scaler_poly__households^3',
#        'robust_scaler_poly__households^2 housing_median_age',
#        'robust_scaler_poly__households^2 latitude',
#        'robust_scaler_poly__households^2 longitude',
#        'robust_scaler_poly__households^2 median_income',
#        'robust_scaler_poly__households^2 population',
#        'robust_scaler_poly__households^2 population_per_household',
#        'robust_scaler_poly__households^2 rooms_per_household',
#        'robust_scaler_poly__households^2 total_bedrooms',
#        'robust_scaler_poly__households^2 total_rooms',
#        'robust_scaler_poly__households housing_median_age^2',
#        'robust_scaler_poly__households housing_median_age latitude',
#        'robust_scaler_poly__households housing_median_age longitude',
#        'robust_scaler_poly__households housing_median_age median_income',
#        'robust_scaler_poly__households housing_median_age population',
#        'robust_scaler_poly__households housing_median_age population_per_household',
#        'robust_scaler_poly__households housing_median_age rooms_per_household',
#        'robust_scaler_poly__households housing_median_age total_bedrooms',
#        'robust_scaler_poly__households housing_median_age total_rooms',
#        'robust_scaler_poly__households latitude^2',
#        'robust_scaler_poly__households latitude longitude',
#        'robust_scaler_poly__households latitude median_income',
#        'robust_scaler_poly__households latitude population',
#        'robust_scaler_poly__households latitude population_per_household',
#        'robust_scaler_poly__households latitude rooms_per_household',
#        'robust_scaler_poly__households latitude total_bedrooms',
#        'robust_scaler_poly__households latitude total_rooms',
#        'robust_scaler_poly__households longitude^2',
#        'robust_scaler_poly__households longitude median_income',
#        'robust_scaler_poly__households longitude population',
#        'robust_scaler_poly__households longitude population_per_household',
#        'robust_scaler_poly__households longitude rooms_per_household',
#        'robust_scaler_poly__households longitude total_bedrooms',
#        'robust_scaler_poly__households longitude total_rooms',
#        'robust_scaler_poly__households median_income^2',
#        'robust_scaler_poly__households median_income population',
#        'robust_scaler_poly__households median_income population_per_household',
#        'robust_scaler_poly__households median_income rooms_per_household',
#        'robust_scaler_poly__households median_income total_bedrooms',
#        'robust_scaler_poly__households median_income total_rooms',
#        'robust_scaler_poly__households population^2',
#        'robust_scaler_poly__households population population_per_household',
#        'robust_scaler_poly__households population rooms_per_household',
#        'robust_scaler_poly__households population total_bedrooms',
#        'robust_scaler_poly__households population total_rooms',
#        'robust_scaler_poly__households population_per_household^2',
#        'robust_scaler_poly__households population_per_household rooms_per_household',
#        'robust_scaler_poly__households population_per_household total_bedrooms',
#        'robust_scaler_poly__households population_per_household total_rooms',
#        'robust_scaler_poly__households rooms_per_household^2',
#        'robust_scaler_poly__households rooms_per_household total_bedrooms',
#        'robust_scaler_poly__households rooms_per_household total_rooms',
#        'robust_scaler_poly__households total_bedrooms^2',
#        'robust_scaler_poly__households total_bedrooms total_rooms',
#        'robust_scaler_poly__households total_rooms^2',
#        'robust_scaler_poly__housing_median_age^3',
#        'robust_scaler_poly__housing_median_age^2 latitude',
#        'robust_scaler_poly__housing_median_age^2 longitude',
#        'robust_scaler_poly__housing_median_age^2 median_income',
#        'robust_scaler_poly__housing_median_age^2 population',
#        'robust_scaler_poly__housing_median_age^2 population_per_household',
#        'robust_scaler_poly__housing_median_age^2 rooms_per_household',
#        'robust_scaler_poly__housing_median_age^2 total_bedrooms',
#        'robust_scaler_poly__housing_median_age^2 total_rooms',
#        'robust_scaler_poly__housing_median_age latitude^2',
#        'robust_scaler_poly__housing_median_age latitude longitude',
#        'robust_scaler_poly__housing_median_age latitude median_income',
#        'robust_scaler_poly__housing_median_age latitude population',
#        'robust_scaler_poly__housing_median_age latitude population_per_household',
#        'robust_scaler_poly__housing_median_age latitude rooms_per_household',
#        'robust_scaler_poly__housing_median_age latitude total_bedrooms',
#        'robust_scaler_poly__housing_median_age latitude total_rooms',
#        'robust_scaler_poly__housing_median_age longitude^2',
#        'robust_scaler_poly__housing_median_age longitude median_income',
#        'robust_scaler_poly__housing_median_age longitude population',
#        'robust_scaler_poly__housing_median_age longitude population_per_household',
#        'robust_scaler_poly__housing_median_age longitude rooms_per_household',
#        'robust_scaler_poly__housing_median_age longitude total_bedrooms',
#        'robust_scaler_poly__housing_median_age longitude total_rooms',
#        'robust_scaler_poly__housing_median_age median_income^2',
#        'robust_scaler_poly__housing_median_age median_income population',
#        'robust_scaler_poly__housing_median_age median_income population_per_household',
#        'robust_scaler_poly__housing_median_age median_income rooms_per_household',
#        'robust_scaler_poly__housing_median_age median_income total_bedrooms',
#        'robust_scaler_poly__housing_median_age median_income total_rooms',
#        'robust_scaler_poly__housing_median_age population^2',
#        'robust_scaler_poly__housing_median_age population population_per_household',
#        'robust_scaler_poly__housing_median_age population rooms_per_household',
#        'robust_scaler_poly__housing_median_age population total_bedrooms',
#        'robust_scaler_poly__housing_median_age population total_rooms',
#        'robust_scaler_poly__housing_median_age population_per_household^2',
#        'robust_scaler_poly__housing_median_age population_per_household rooms_per_household',
#        'robust_scaler_poly__housing_median_age population_per_household total_bedrooms',
#        'robust_scaler_poly__housing_median_age population_per_household total_rooms',
#        'robust_scaler_poly__housing_median_age rooms_per_household^2',
#        'robust_scaler_poly__housing_median_age rooms_per_household total_bedrooms',
#        'robust_scaler_poly__housing_median_age rooms_per_household total_rooms',
#        'robust_scaler_poly__housing_median_age total_bedrooms^2',
#        'robust_scaler_poly__housing_median_age total_bedrooms total_rooms',
#        'robust_scaler_poly__housing_median_age total_rooms^2',
#        'robust_scaler_poly__latitude^3',
#        'robust_scaler_poly__latitude^2 longitude',
#        'robust_scaler_poly__latitude^2 median_income',
#        'robust_scaler_poly__latitude^2 population',
#        'robust_scaler_poly__latitude^2 population_per_household',
#        'robust_scaler_poly__latitude^2 rooms_per_household',
#        'robust_scaler_poly__latitude^2 total_bedrooms',
#        'robust_scaler_poly__latitude^2 total_rooms',
#        'robust_scaler_poly__latitude longitude^2',
#        'robust_scaler_poly__latitude longitude median_income',
#        'robust_scaler_poly__latitude longitude population',
#        'robust_scaler_poly__latitude longitude population_per_household',
#        'robust_scaler_poly__latitude longitude rooms_per_household',
#        'robust_scaler_poly__latitude longitude total_bedrooms',
#        'robust_scaler_poly__latitude longitude total_rooms',
#        'robust_scaler_poly__latitude median_income^2',
#        'robust_scaler_poly__latitude median_income population',
#        'robust_scaler_poly__latitude median_income population_per_household',
#        'robust_scaler_poly__latitude median_income rooms_per_household',
#        'robust_scaler_poly__latitude median_income total_bedrooms',
#        'robust_scaler_poly__latitude median_income total_rooms',
#        'robust_scaler_poly__latitude population^2',
#        'robust_scaler_poly__latitude population population_per_household',
#        'robust_scaler_poly__latitude population rooms_per_household',
#        'robust_scaler_poly__latitude population total_bedrooms',
#        'robust_scaler_poly__latitude population total_rooms',
#        'robust_scaler_poly__latitude population_per_household^2',
#        'robust_scaler_poly__latitude population_per_household rooms_per_household',
#        'robust_scaler_poly__latitude population_per_household total_bedrooms',
#        'robust_scaler_poly__latitude population_per_household total_rooms',
#        'robust_scaler_poly__latitude rooms_per_household^2',
#        'robust_scaler_poly__latitude rooms_per_household total_bedrooms',
#        'robust_scaler_poly__latitude rooms_per_household total_rooms',
#        'robust_scaler_poly__latitude total_bedrooms^2',
#        'robust_scaler_poly__latitude total_bedrooms total_rooms',
#        'robust_scaler_poly__latitude total_rooms^2',
#        'robust_scaler_poly__longitude^3',
#        'robust_scaler_poly__longitude^2 median_income',
#        'robust_scaler_poly__longitude^2 population',
#        'robust_scaler_poly__longitude^2 population_per_household',
#        'robust_scaler_poly__longitude^2 rooms_per_household',
#        'robust_scaler_poly__longitude^2 total_bedrooms',
#        'robust_scaler_poly__longitude^2 total_rooms',
#        'robust_scaler_poly__longitude median_income^2',
#        'robust_scaler_poly__longitude median_income population',
#        'robust_scaler_poly__longitude median_income population_per_household',
#        'robust_scaler_poly__longitude median_income rooms_per_household',
#        'robust_scaler_poly__longitude median_income total_bedrooms',
#        'robust_scaler_poly__longitude median_income total_rooms',
#        'robust_scaler_poly__longitude population^2',
#        'robust_scaler_poly__longitude population population_per_household',
#        'robust_scaler_poly__longitude population rooms_per_household',
#        'robust_scaler_poly__longitude population total_bedrooms',
#        'robust_scaler_poly__longitude population total_rooms',
#        'robust_scaler_poly__longitude population_per_household^2',
#        'robust_scaler_poly__longitude population_per_household rooms_per_household',
#        'robust_scaler_poly__longitude population_per_household total_bedrooms',
#        'robust_scaler_poly__longitude population_per_household total_rooms',
#        'robust_scaler_poly__longitude rooms_per_household^2',
#        'robust_scaler_poly__longitude rooms_per_household total_bedrooms',
#        'robust_scaler_poly__longitude rooms_per_household total_rooms',
#        'robust_scaler_poly__longitude total_bedrooms^2',
#        'robust_scaler_poly__longitude total_bedrooms total_rooms',
#        'robust_scaler_poly__longitude total_rooms^2',
#        'robust_scaler_poly__median_income^3',
#        'robust_scaler_poly__median_income^2 population',
#        'robust_scaler_poly__median_income^2 population_per_household',
#        'robust_scaler_poly__median_income^2 rooms_per_household',
#        'robust_scaler_poly__median_income^2 total_bedrooms',
#        'robust_scaler_poly__median_income^2 total_rooms',
#        'robust_scaler_poly__median_income population^2',
#        'robust_scaler_poly__median_income population population_per_household',
#        'robust_scaler_poly__median_income population rooms_per_household',
#        'robust_scaler_poly__median_income population total_bedrooms',
#        'robust_scaler_poly__median_income population total_rooms',
#        'robust_scaler_poly__median_income population_per_household^2',
#        'robust_scaler_poly__median_income population_per_household rooms_per_household',
#        'robust_scaler_poly__median_income population_per_household total_bedrooms',
#        'robust_scaler_poly__median_income population_per_household total_rooms',
#        'robust_scaler_poly__median_income rooms_per_household^2',
#        'robust_scaler_poly__median_income rooms_per_household total_bedrooms',
#        'robust_scaler_poly__median_income rooms_per_household total_rooms',
#        'robust_scaler_poly__median_income total_bedrooms^2',
#        'robust_scaler_poly__median_income total_bedrooms total_rooms',
#        'robust_scaler_poly__median_income total_rooms^2',
#        'robust_scaler_poly__population^3',
#        'robust_scaler_poly__population^2 population_per_household',
#        'robust_scaler_poly__population^2 rooms_per_household',
#        'robust_scaler_poly__population^2 total_bedrooms',
#        'robust_scaler_poly__population^2 total_rooms',
#        'robust_scaler_poly__population population_per_household^2',
#        'robust_scaler_poly__population population_per_household rooms_per_household',
#        'robust_scaler_poly__population population_per_household total_bedrooms',
#        'robust_scaler_poly__population population_per_household total_rooms',
#        'robust_scaler_poly__population rooms_per_household^2',
#        'robust_scaler_poly__population rooms_per_household total_bedrooms',
#        'robust_scaler_poly__population rooms_per_household total_rooms',
#        'robust_scaler_poly__population total_bedrooms^2',
#        'robust_scaler_poly__population total_bedrooms total_rooms',
#        'robust_scaler_poly__population total_rooms^2',
#        'robust_scaler_poly__population_per_household^3',
#        'robust_scaler_poly__population_per_household^2 rooms_per_household',
#        'robust_scaler_poly__population_per_household^2 total_bedrooms',
#        'robust_scaler_poly__population_per_household^2 total_rooms',
#        'robust_scaler_poly__population_per_household rooms_per_household^2',
#        'robust_scaler_poly__population_per_household rooms_per_household total_bedrooms',
#        'robust_scaler_poly__population_per_household rooms_per_household total_rooms',
#        'robust_scaler_poly__population_per_household total_bedrooms^2',
#        'robust_scaler_poly__population_per_household total_bedrooms total_rooms',
#        'robust_scaler_poly__population_per_household total_rooms^2',
#        'robust_scaler_poly__rooms_per_household^3',
#        'robust_scaler_poly__rooms_per_household^2 total_bedrooms',
#        'robust_scaler_poly__rooms_per_household^2 total_rooms',
#        'robust_scaler_poly__rooms_per_household total_bedrooms^2',
#        'robust_scaler_poly__rooms_per_household total_bedrooms total_rooms',
#        'robust_scaler_poly__rooms_per_household total_rooms^2',
#        'robust_scaler_poly__total_bedrooms^3',
#        'robust_scaler_poly__total_bedrooms^2 total_rooms',
#        'robust_scaler_poly__total_bedrooms total_rooms^2',
#        'robust_scaler_poly__total_rooms^3'], dtype=object)

# %%
grid_search.best_estimator_.regressor_['reg'].coef_          # os coeficientes estão numa faixa bem menor do que antes
# Out:
# array([-4.65127492e-01, -1.98525858e-01, -5.50635757e-02, -8.02828973e-03,
#         3.38287228e-01, -2.77243600e-02,  1.32959223e-01, -9.56368256e-01,
#        -1.02687928e+00,  9.83428229e-01, -1.40132817e-01, -3.33250013e-01,
#         1.36799509e-01,  1.69693115e-01,  2.78703714e-02,  2.02252685e-03,
#         1.04500739e-01,  4.82773895e-02, -1.21545681e-01, -1.40763536e-01,
#         1.86073495e-01,  5.51971588e-02, -1.43394733e-01, -1.80334688e-01,
#        -6.56652260e-02,  3.80935163e-02, -7.16686498e-03,  4.38098084e-02,
#         5.79294025e-02,  1.07634082e-03,  6.00904965e-02,  2.04711908e-02,
#         4.35827842e-02,  1.27763098e-02,  4.31259266e-02, -4.98619346e-03,
#        -3.90422373e-03, -3.12697656e-01, -2.69208726e-01,  2.50335971e-01,
#        -2.38483914e-02, -1.69542049e-01, -1.03872972e-01,  6.41865502e-02,
#        -2.73816298e-02, -3.30929062e-01, -2.41106727e-01, -7.92119645e-02,
#         4.56488465e-02,  3.82360742e-02,  7.99178621e-02,  1.16492545e-02,
#         4.10097489e-02, -3.06204050e-02, -1.94882192e-01,  1.00692779e-01,
#         1.55111303e-01,  1.05184443e-01, -1.95252240e-02,  3.55274358e-02,
#        -7.54336285e-02, -3.03733258e-02, -1.10726475e-01,  8.44399185e-02,
#         1.24368423e-01,  9.03152054e-02,  7.03717132e-03,  3.58814472e-02,
#        -4.79632969e-02, -4.10083306e-03, -1.70634449e-02,  4.40855568e-02,
#        -1.04246724e-01, -7.70156414e-02, -2.15097040e-02, -2.56402925e-02,
#        -6.72682175e-02,  3.34968102e-02, -1.76648908e-02,  2.03416009e-02,
#        -2.61034645e-03, -6.57794802e-02,  8.53957635e-02, -5.73795719e-02,
#        -6.45934179e-02, -1.57088025e-01, -2.31368119e-01,  2.37188754e-02,
#         3.77882593e-02,  7.35664993e-02,  3.32924017e-02, -3.30800911e-01,
#        -3.80923163e-02, -1.33883313e-01, -3.53207158e-02,  1.02301127e-01,
#        -7.70231090e-02, -6.33776061e-02,  3.74707579e-02, -1.31376615e-02,
#         3.53829267e-02,  2.41597764e-02, -5.20083328e-02,  1.23880571e-01,
#         1.08964475e-01, -1.33085211e-01,  6.59333372e-02, -2.03103447e-02,
#        -6.36307602e-02, -1.41651743e-01,  2.46419928e-01, -2.79138977e-02,
#         1.48121633e-01, -2.97976367e-02,  1.92072180e-02,  7.10709976e-02,
#         4.94668159e-02,  6.28830806e-02,  1.98134007e-02, -1.24415528e-01,
#         2.14173652e-02, -1.66262766e-02,  1.61838867e-01, -5.91531469e-02,
#         5.05134694e-02, -4.41506958e-02, -1.73828629e-01,  8.90098095e-02,
#         2.08818600e-02, -2.22582784e-02, -1.33523290e-01, -7.90743057e-02,
#        -2.73587677e-02, -1.42801134e-01, -6.06700174e-02, -9.66281805e-02,
#        -3.47196422e-02,  2.75016724e-02,  5.62372569e-02,  7.49693221e-02,
#        -1.55919979e-02, -4.90696964e-02,  1.74860379e-01, -9.55083470e-02,
#         9.61517662e-02, -3.35951318e-02,  2.83706267e-02, -1.52620673e-02,
#         1.41603300e-02,  6.48306511e-02,  6.14642283e-02, -4.65279661e-02,
#         1.13104356e-01,  3.72898114e-02, -7.53566709e-03, -2.77923554e-02,
#        -5.79964240e-02,  1.85881588e-02, -4.16579961e-03, -3.04294555e-02,
#         8.49673674e-02,  9.46110970e-02, -4.82270846e-03, -1.17423977e-01,
#        -7.84064603e-02, -9.21677407e-02, -9.84577116e-02,  1.01193684e-01,
#        -2.21279347e-01, -2.92157660e-02, -1.32936270e-01, -1.04009050e-01,
#        -2.07910594e-02,  1.01677897e-01, -8.25753173e-02,  4.26508754e-02,
#         9.08461914e-02,  9.61391888e-02,  4.38173945e-02, -2.39432318e-02,
#        -4.08462987e-02, -1.86531200e-01,  6.55417273e-02, -1.20894630e-01,
#        -6.53310528e-02, -4.04503111e-02, -3.92515646e-02, -8.50637380e-02,
#        -9.86671295e-02, -5.80380576e-02, -3.04653403e-02,  6.12335731e-03,
#        -9.70265805e-02, -6.76040835e-02, -5.30886047e-02, -1.28108617e-02,
#         9.66374872e-02, -6.68474547e-04, -3.72639520e-02,  3.38467976e-02,
#        -2.76882798e-02,  4.18678920e-02, -3.34848276e-02,  2.54652460e-02,
#         1.71195691e-02, -5.19081628e-02,  5.29045248e-02, -1.80401427e-02,
#        -9.04120041e-03, -5.28833189e-02, -4.13756918e-02, -9.89691088e-02,
#         1.40736809e-01, -4.04623534e-02,  3.37160977e-02,  9.33491449e-02,
#         1.55123638e-01, -2.10709974e-02, -1.71240641e-02,  2.15772796e-01,
#         8.17420400e-02, -3.43978820e-02,  2.08056358e-02,  5.42386103e-02,
#         3.95606431e-02, -1.39300758e-02, -8.82319904e-02,  4.90945976e-02,
#        -1.80541913e-01, -4.18288072e-03, -5.12791150e-02, -3.41603301e-02,
#        -9.64233939e-02,  6.25533267e-02,  4.60809914e-02,  4.11115458e-02,
#         5.27485015e-02,  8.83658231e-02,  1.57719056e-02, -1.96198290e-01,
#         1.53483265e-01, -6.09567078e-04, -1.37446815e-01,  7.63282850e-02,
#        -4.30266031e-02,  6.00656994e-02,  2.67268955e-02,  2.28512266e-01,
#         2.49669500e-01, -1.62877257e-01, -2.25920248e-01, -1.38660857e-01,
#        -1.21182943e-01,  6.68174326e-02,  1.43706793e-01, -2.33324596e-01,
#        -7.24682335e-02, -6.16009544e-02, -4.16659420e-01, -1.26120969e-01,
#        -7.85501373e-02, -8.73047885e-02, -5.85520050e-02,  1.21783561e-01,
#         2.46396864e-01,  5.76028515e-02, -2.32283406e-02,  5.74691654e-02,
#         2.29206263e-02, -5.54789227e-02,  2.68801864e-02, -2.20810066e-02,
#         6.34099885e-02,  9.06163162e-02,  2.78226304e-02,  1.34860769e-01,
#        -8.36674034e-04, -1.48768800e-02, -6.22984616e-02,  6.86546069e-02,
#        -1.26866035e-01, -9.62861546e-02, -4.00070412e-03, -2.21317675e-01,
#        -4.06683101e-02,  9.25498136e-02, -5.66884990e-02, -2.05299768e-01,
#        -2.08940100e-02, -1.75096701e-03, -1.47199752e-02,  1.31846350e-01,
#         2.08384588e-01,  1.08486431e-01, -7.08126577e-02, -7.71590514e-02,
#        -6.83445269e-03, -2.13485428e-02, -2.03263558e-02, -1.13492597e-01,
#         2.78203424e-02,  4.21355727e-02,  6.36924776e-02, -1.69087935e-01,
#         3.61931804e-02, -3.39728252e-02,  1.50990349e-02, -4.61253367e-02,
#        -5.76695351e-02, -4.62763520e-02,  5.97086091e-02, -3.02027710e-02,
#        -2.11605135e-02,  1.27635333e-03, -2.67014407e-02, -9.81252415e-04,
#         8.66722595e-02, -4.85957735e-02,  1.75142065e-01,  1.75073868e-01,
#        -4.21838342e-02,  9.21219531e-02, -3.03053690e-02, -6.26984886e-02,
#        -2.83805693e-01,  1.19463332e-01, -5.68273525e-02, -9.60317709e-02,
#        -6.31152213e-02,  1.19832182e-02,  9.08562833e-03, -1.22716412e-02,
#        -7.95147128e-04,  2.73538923e-02,  3.93871055e-03,  8.17112534e-02,
#        -6.90652413e-02,  2.15238039e-02,  6.25967510e-03,  1.43690575e-01,
#        -3.69988779e-02,  3.21300538e-02,  4.49124114e-02, -5.63213700e-02,
#        -4.32262477e-02, -3.42548482e-02,  9.94854781e-02,  8.92559453e-04,
#         8.01213033e-03,  1.17937029e-01, -2.41561831e-02,  4.44973670e-02,
#         1.44739893e-01, -1.32981935e-01,  8.66998693e-02, -9.34742205e-03,
#        -3.25007487e-02,  3.64887324e-02,  4.32883550e-02, -1.32997404e-01,
#        -8.60749066e-02, -3.88456025e-02,  1.26706671e-01, -1.24702941e-02,
#         2.11781560e-02,  7.94974164e-02, -8.18704259e-02])

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_['reg'].coef_, 
    grid_search.best_estimator_.regressor_['preprocessor'].get_feature_names_out()
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude                         -1.026879
# robust_scaler_poly__latitude                          -0.956368
# one_hot_encoder__ocean_proximity_INLAND               -0.465127
# robust_scaler_poly__latitude longitude populati...    -0.416659
# robust_scaler_poly__population_per_household          -0.333250
# ...                                                         ...
# robust_scaler_poly__bedrooms_per_room housing_m...     0.246420
# robust_scaler_poly__latitude^2 longitude               0.249670
# robust_scaler_poly__housing_median_age median_i...     0.250336
# robust_scaler_poly__bedrooms_per_room                  0.338287
# robust_scaler_poly__median_income                      0.983428
#
# [367 rows x 1 columns]

# %%
coefs[coefs['coeficiente'] == 0]        # Voltamos a não ter nenhum coeficiente zerado, pois agora estamos usando apenas o Ridge, e não tem mais efeito do Lasso dentro do Elasticnet

# Lasso --> zera os coeficiente de menor importância
# Ridget --> diminuir os coeficientes de menor importância, mas não tende a zerá-los
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs['coeficiente'].between(-0.2, 0.2)]        # Repare que temos 301 nessa faixa coeficientes entre essa
# Out:
#                                                     coeficiente
# one_hot_encoder__ocean_proximity_NEAR BAY             -0.198526
# robust_scaler_poly__housing_median_age populati...    -0.196198
# robust_scaler_poly__longitude median_income           -0.194882
# robust_scaler_poly__households median_income^2        -0.186531
# robust_scaler_poly__housing_median_age median_i...    -0.180542
# ...                                                         ...
# robust_scaler_poly__total_bedrooms                     0.169693
# robust_scaler_poly__bedrooms_per_room rooms_per...     0.174860
# robust_scaler_poly__median_income population ro...     0.175074
# robust_scaler_poly__median_income population po...     0.175142
# robust_scaler_poly__bedrooms_per_room median_in...     0.186073
#
# [341 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs['coeficiente'].between(-0.2, 0.2)])

# Veja que agora temos muitos coeficientes que são iguais às colunas originais do dataframe, 
# Ou seja, colocar um regularização pode ajudar a simplificar o modelo e torná-lo mais fácil de entender

# %% [markdown]
# #### **Comparando os modelos acima criados com o modelo com os melhores estimadores pelo GridSearchCV**

# %%
regressors = {
    "DummyRegressor": {
        'preprocessor': None,
        'regressor': DummyRegressor(strategy='mean'),
        'target_transformer': None
    },
    "LinearRegression": {
        'preprocessor': preprocessamento,
        'regressor': LinearRegression(),
        'target_transformer': None
    },
    "LinearRegression + Target Transformer": {    # Incluído esse regressor, pois aí a unica diferença pro GridSearch será as Polynomial Features (no proprocessamento tava definido grau 1)
        'preprocessor': preprocessamento,
        'regressor': LinearRegression(),
        'target_transformer': QuantileTransformer(output_distribution='normal')
    },
    "Ridge_GridSearchCV": {
        'preprocessor': grid_search.best_estimator_.regressor_['preprocessor'],
        'regressor': grid_search.best_estimator_.regressor_['reg'],
        'target_transformer': grid_search.best_estimator_.transformer
    }, 
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor) for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)
df_resultados
# Out:
#                                     model  fit_time score_time   test_r2  \
# 0                          DummyRegressor  0.013556   0.017949 -0.000081
# 1                          DummyRegressor  0.009968   0.014955 -0.000146
# 2                          DummyRegressor  0.008857   0.017635 -0.001737
# 3                          DummyRegressor   0.01197   0.011966 -0.000101
# 4                          DummyRegressor  0.008696   0.012899 -0.000114
# 5                        LinearRegression  0.282356   0.032665  0.682162
# 6                        LinearRegression  0.249118   0.026695   0.66999
# 7                        LinearRegression  0.239257   0.031914  0.649247
# 8                        LinearRegression  0.253154   0.031418  0.669873
# 9                        LinearRegression  0.151327   0.028018  0.669023
# 10  LinearRegression + Target Transformer  0.198296   0.028884  0.691585
# 11  LinearRegression + Target Transformer  0.198467   0.027828  0.678223
# 12  LinearRegression + Target Transformer   0.25049   0.032911  0.653101
# 13  LinearRegression + Target Transformer  0.299445   0.030918  0.684062
# 14  LinearRegression + Target Transformer  0.128819   0.027956  0.682724
# 15                     Ridge_GridSearchCV  0.630502   0.072716  0.744094
# 16                     Ridge_GridSearchCV  0.563413   0.052062  0.723665
# 17                     Ridge_GridSearchCV  0.714775   0.068821  0.698007
# 18                     Ridge_GridSearchCV  0.514573   0.066822  0.725039
# 19                     Ridge_GridSearchCV  0.549906   0.059629  0.725666
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.031505
# 1                 -75787.787194                    -95217.629397     0.024923
# 2                 -76753.598961                    -96253.253947     0.026492
# 3                 -76837.804811                    -95983.885799     0.023937
# 4                 -76617.245449                    -96182.764729     0.021595
# 5                 -39855.690996                    -54254.958188      0.31502
# 6                 -40272.565467                    -54695.230283     0.275813
# 7                  -42178.05929                    -56955.988706     0.271171
# 8                 -40806.492497                    -55146.318803     0.284571
# 9                 -40788.496497                     -55331.35106     0.179345
# 10                -37806.227921                    -53444.642129      0.22718
# 11                -38277.588229                    -54008.675235     0.226294
# 12                -40301.671951                    -56642.165513     0.283401
# 13                -38605.906917                     -53948.27087     0.330363
# 14                -38424.806297                    -54174.010756     0.156775
# 15                -34104.212271                    -48682.980123     0.703218
# 16                -35013.651675                    -50049.933159     0.615475
# 17                -37076.138697                    -52848.991011     0.783595
# 18                -35249.475197                     -50328.29266     0.581395
# 19                 -35251.26757                    -50374.658157     0.609535

# %%
df_resultados.groupby('model').mean().sort_values(by='test_neg_root_mean_squared_error')
# Out:
#                                        fit_time score_time   test_r2  \
# model
# DummyRegressor                         0.048414   0.008527 -0.000436
# LinearRegression                       0.074012   0.016002  0.668059
# LinearRegression + Target Transformer  0.144597   0.021074  0.678281
# Ridge_GridSearchCV                     0.293234   0.033823  0.723303
#
#                                       test_neg_mean_absolute_error  \
# model
# DummyRegressor                                       -76702.495836
# LinearRegression                                      -40780.26095
# LinearRegression + Target Transformer                -38674.462679
# Ridge_GridSearchCV                                   -35340.237852
#
#                                       test_neg_root_mean_squared_error  \
# model
# DummyRegressor                                           -95975.447913
# LinearRegression                                         -55276.769408
# LinearRegression + Target Transformer                    -54415.155013
# Ridge_GridSearchCV                                       -50456.412261
#
#                                       time_seconds
# model
# DummyRegressor                            0.056941
# LinearRegression                          0.090014
# LinearRegression + Target Transformer     0.165671
# Ridge_GridSearchCV                        0.327057

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %% [markdown]
# ### <font color = 'darkblue'> **Salvando o melhor modelo**

# %%
from pathlib import Path

# Pasta do noteook atual
Path().resolve()

# %%
dump(grid_search.best_estimator_, Path().resolve().parents[0]/"modelos"/"ridge_polyfeat_target_quantile.joblib")
